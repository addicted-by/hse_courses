# %%
import pandas as pd
import numpy as np
import os 
from sklearn.linear_model import LinearRegression


DATA_PATH = "./WaitData.Published.xlsx"
assert os.path.exists(DATA_PATH), f"PATH {DATA_PATH} does not exist"

# %%
df = pd.read_excel(DATA_PATH, sheet_name='F3')

# %%
df
# Out:
#        Wait       x_ArrivalDTTM     x_ScheduledDTTM         x_BeginDTTM  \
# 0         0 2025-08-02 16:47:44 2025-08-02 17:45:00 2025-08-02 17:45:03
# 1        -3 2025-08-02 16:38:46 2025-08-02 17:15:00 2025-08-02 17:12:14
# 2       -25 2025-08-02 16:29:25 2025-08-02 17:30:00 2025-08-02 17:05:15
# 3        36 2025-08-02 16:16:24 2025-08-02 16:45:00 2025-08-02 17:21:55
# 4       -21 2025-08-02 16:04:36 2025-08-02 17:15:00 2025-08-02 16:54:49
# ...     ...                 ...                 ...                 ...
# 23578    38 2023-10-06 08:59:20 2023-10-06 09:00:00 2023-10-06 09:38:45
# 23579     8 2023-10-06 08:40:18 2023-10-06 09:45:00 2023-10-06 09:53:06
# 23580    12 2023-10-06 08:38:36 2023-10-06 09:30:00 2023-10-06 09:42:46
# 23581     2 2023-10-06 08:31:42 2023-10-06 09:15:00 2023-10-06 09:17:00
# 23582     2 2023-10-06 08:12:31 2023-10-06 09:30:00 2023-10-06 09:32:46
#
#        SumHowEarlyWaiting  AvgHowEarlyWaiting  LineCount0Strict  SumWaits  \
# 0                     372                  62                 6       249
# 1                     335                  67                 3       195
# 2                     274                  68                 4       150
# 3                     369                  73                 2       179
# 4                     438                  73                 5       192
# ...                   ...                 ...               ...       ...
# 23578                 239                  59                 0       115
# 23579                 174                  58                 3        39
# 23580                 122                  61                 2        33
# 23581                  78                  78                 0        19
# 23582                   0                   0                 0         0
#
#        LineCount0  LineCount1  ...  NumAddOnsToday  NumAddOnsLastW2  \
# 0               6           5  ...               4                2
# 1               5           4  ...               4                1
# 2               4           5  ...               4                1
# 3               5           6  ...               3                1
# 4               6           5  ...               3                0
# ...           ...         ...  ...             ...              ...
# 23578           4           4  ...               0                0
# 23579           3           1  ...               0                0
# 23580           2           1  ...               0                0
# 23581           1           1  ...               0                0
# 23582           0           0  ...               0                0
#
#        NumScheduledNextSlot  NumScheduledNextW2  SumTimeToCompleteNextSlot  \
# 0                         0                   0                          0
# 1                         2                   0                         32
# 2                         1                   1                         13
# 3                         2                   1                         45
# 4                         2                   1                         32
# ...                     ...                 ...                        ...
# 23578                     1                   1                         14
# 23579                     2                   1                         33
# 23580                     2                   1                         34
# 23581                     2                   2                         40
# 23582                     2                   1                         34
#
#        SumTimeToCompleteNextW2  WithContrastCountWaiting  \
# 0                            0                         3
# 1                            0                         2
# 2                           16                         1
# 3                           16                         3
# 4                           15                         4
# ...                        ...                       ...
# 23578                       17                         3
# 23579                       13                         2
# 23580                       13                         1
# 23581                       33                         1
# 23582                       13                         0
#
#        WithAndWithoutContrastCountWaiting  WithContrastCountInProgress  \
# 0                                       1                            1
# 1                                       1                            2
# 2                                       1                            3
# 3                                       1                            1
# 4                                       0                            0
# ...                                   ...                          ...
# 23578                                   0                            0
# 23579                                   0                            0
# 23580                                   0                            0
# 23581                                   0                            0
# 23582                                   0                            0
#
#        WithAndWithoutContrastCountInProgress
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          1
# ...                                      ...
# 23578                                      0
# 23579                                      0
# 23580                                      0
# 23581                                      0
# 23582                                      0
#
# [23583 rows x 89 columns]

# %%
df = df[~df['DayOfYear'].isna()]
columns_to_drop = ['Wait', 'x_ArrivalDTTM', 'x_ScheduledDTTM', 'x_BeginDTTM']
X = df.drop(columns=columns_to_drop)
y = df['Wait'].values

# %%
X
# Out:
#        SumHowEarlyWaiting  AvgHowEarlyWaiting  LineCount0Strict  SumWaits  \
# 0                     372                  62                 6       249
# 1                     335                  67                 3       195
# 2                     274                  68                 4       150
# 3                     369                  73                 2       179
# 4                     438                  73                 5       192
# ...                   ...                 ...               ...       ...
# 23578                 239                  59                 0       115
# 23579                 174                  58                 3        39
# 23580                 122                  61                 2        33
# 23581                  78                  78                 0        19
# 23582                   0                   0                 0         0
#
#        LineCount0  LineCount1  LineCount2  LineCount3  LineCount4  FlowCount2  \
# 0               6           5           6           6           4           2
# 1               5           4           6           6           5           3
# 2               4           5           6           4           6           4
# 3               5           6           4           5           5           3
# 4               6           5           5           6           5           2
# ...           ...         ...         ...         ...         ...         ...
# 23578           4           4           1           1           0           0
# 23579           3           1           0           0           0           0
# 23580           2           1           0           0           0           0
# 23581           1           1           0           0           0           0
# 23582           0           0           0           0           0           0
#
#        ...  NumAddOnsToday  NumAddOnsLastW2  NumScheduledNextSlot  \
# 0      ...               4                2                     0
# 1      ...               4                1                     2
# 2      ...               4                1                     1
# 3      ...               3                1                     2
# 4      ...               3                0                     2
# ...    ...             ...              ...                   ...
# 23578  ...               0                0                     1
# 23579  ...               0                0                     2
# 23580  ...               0                0                     2
# 23581  ...               0                0                     2
# 23582  ...               0                0                     2
#
#        NumScheduledNextW2  SumTimeToCompleteNextSlot  SumTimeToCompleteNextW2  \
# 0                       0                          0                        0
# 1                       0                         32                        0
# 2                       1                         13                       16
# 3                       1                         45                       16
# 4                       1                         32                       15
# ...                   ...                        ...                      ...
# 23578                   1                         14                       17
# 23579                   1                         33                       13
# 23580                   1                         34                       13
# 23581                   2                         40                       33
# 23582                   1                         34                       13
#
#        WithContrastCountWaiting  WithAndWithoutContrastCountWaiting  \
# 0                             3                                   1
# 1                             2                                   1
# 2                             1                                   1
# 3                             3                                   1
# 4                             4                                   0
# ...                         ...                                 ...
# 23578                         3                                   0
# 23579                         2                                   0
# 23580                         1                                   0
# 23581                         1                                   0
# 23582                         0                                   0
#
#        WithContrastCountInProgress  WithAndWithoutContrastCountInProgress
# 0                                1                                      0
# 1                                2                                      0
# 2                                3                                      0
# 3                                1                                      0
# 4                                0                                      1
# ...                            ...                                    ...
# 23578                            0                                      0
# 23579                            0                                      0
# 23580                            0                                      0
# 23581                            0                                      0
# 23582                            0                                      0
#
# [23583 rows x 85 columns]

# %% [markdown]
# # Q5

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(X, y)
Ypred = model.predict(X) # use trained regression model to predict
r = y-Ypred # compute prediction error (residual)
e = abs(r).mean() # compute model error

print("Check the correctness: ", np.median(abs(r)))
print("Question 5: ", e)

# %%
e
# Out:
# 23.166288936347385

# %%
np.median(abs(r))
# Out:
# 19.12606344606968

# %% [markdown]
# # Q6

# %%
# Run Python feature selection
if True: # just in case I want to disable this part
    print('\n>Python feature selection:')
    from sklearn.feature_selection import RFE
    from itertools import compress
    for nFeatures in range(1,4):
        rfe = RFE(model, n_features_to_select=nFeatures)
        X_rfe = rfe.fit_transform(X,y) #transforming data using RFE
     #Fitting the data to model
        model.fit(X_rfe,y)
        #print(rfe.support_)
        #print(rfe.ranking_)
        cols = list(compress(X.columns, rfe.support_))
        model.fit(X[cols],y)
        e = abs(y-model.predict(X[cols])).mean()
        print(e, cols)
# Out:
# >Python feature selection:
# 32.50541172120655 ['CardiacCount']
# 31.224937706982736 ['CardiacCount', 'DelayedInLine']
# 31.25752894868932 ['CardiacCount', 'StartTime', 'DelayedInLine']

# %% [markdown]
# # Q7

# %%
def greedy_feature_selection(X, y, num_features_to_select, verbose: bool=False):
    best_feature_set = []
    best_error = float('inf')

    for num_features_selected in range(num_features_to_select):
        remaining_features = [col for col in X.columns if col not in best_feature_set]
        candidate_errors = []

        for feature_to_add in remaining_features:
            current_feature_set = best_feature_set + [feature_to_add]
            X_subset = X[current_feature_set]
            
            model = LinearRegression()
            model.fit(X_subset, y)
            
            absolute_errors = np.abs(model.predict(X_subset) - y)
            candidate_errors.append(absolute_errors.mean())

        best_candidate_index = np.argmin(candidate_errors)
        best_feature_set.append(remaining_features[best_candidate_index])
        best_error = candidate_errors[best_candidate_index]
        if verbose:
            print(f"{num_features_selected + 1}-feature model. Features:", *best_feature_set, sep=' | ')
            print(f"{num_features_selected + 1}-feature model. Error: ", best_error)
    return best_error, best_feature_set

# %%
best_error, best_feature_set = greedy_feature_selection(X, y, 3, verbose=True)

print("Best 3-feature model features:", best_feature_set)
print("Best error for the best 3-feature model:", best_error)
# Out:
# 1-feature model. Features: | DelayedInLine
# 1-feature model. Error:  31.227057699733514
# 2-feature model. Features: | DelayedInLine | LineCount0Strict
# 2-feature model. Error:  30.137965863467567
# 3-feature model. Features: | DelayedInLine | LineCount0Strict | LineCount0
# 3-feature model. Error:  28.69649063225338
# Best 3-feature model features: ['DelayedInLine', 'LineCount0Strict', 'LineCount0']
# Best error for the best 3-feature model: 28.69649063225338

# %% [markdown]
# # Q8

# %%
num_features_to_select = 15

best_error, best_feature_set = greedy_feature_selection(X, y, num_features_to_select, verbose=True)

print(f"Best {num_features_to_select}-feature model features:", best_feature_set)
print("Best error for the best {num_features_to_select}-feature model:", best_error)
# Out:
# 1-feature model. Features: | DelayedInLine
# 1-feature model. Error:  31.227057699733514
# 2-feature model. Features: | DelayedInLine | LineCount0Strict
# 2-feature model. Error:  30.137965863467567
# 3-feature model. Features: | DelayedInLine | LineCount0Strict | LineCount0
# 3-feature model. Error:  28.69649063225338
# 4-feature model. Features: | DelayedInLine | LineCount0Strict | LineCount0 | SumDelayWaitingInLine
# 4-feature model. Error:  28.2463095851323
# 5-feature model. Features: | DelayedInLine | LineCount0Strict | LineCount0 | SumDelayWaitingInLine | AheadCount
# 5-feature model. Error:  28.147006842164515
# 6-feature model. Features: | DelayedInLine | LineCount0Strict | LineCount0 | SumDelayWaitingInLine | AheadCount | NumCompletedToday
# 6-feature model. Error:  24.989574734774777
# 7-feature model. Features: | DelayedInLine | LineCount0Strict | LineCount0 | SumDelayWaitingInLine | AheadCount | NumCompletedToday | NumScheduledNextW2
# 7-feature model. Error:  24.659186407251333
# 8-feature model. Features: | DelayedInLine | LineCount0Strict | LineCount0 | SumDelayWaitingInLine | AheadCount | NumCompletedToday | NumScheduledNextW2 | DelayCount
# 8-feature model. Error:  24.329071006187288
# 9-feature model. Features: | DelayedInLine | LineCount0Strict | LineCount0 | SumDelayWaitingInLine | AheadCount | NumCompletedToday | NumScheduledNextW2 | DelayCount | InProgressSize
# 9-feature model. Error:  24.071936786758197
# 10-feature model. Features: | DelayedInLine | LineCount0Strict | LineCount0 | SumDelayWaitingInLine | AheadCount | NumCompletedToday | NumScheduledNextW2 | DelayCount | InProgressSize | StartTime4
# 10-feature model. Error:  23.84650949206529
# 11-feature model. Features: | DelayedInLine | LineCount0Strict | LineCount0 | SumDelayWaitingInLine | AheadCount | NumCompletedToday | NumScheduledNextW2 | DelayCount | InProgressSize | StartTime4 | AvgDelayForDay
# 11-feature model. Error:  23.692619398547166
# 12-feature model. Features: | DelayedInLine | LineCount0Strict | LineCount0 | SumDelayWaitingInLine | AheadCount | NumCompletedToday | NumScheduledNextW2 | DelayCount | InProgressSize | StartTime4 | AvgDelayForDay | AvgWaitLastK1Customers
# 12-feature model. Error:  23.627914296582315
# 13-feature model. Features: | DelayedInLine | LineCount0Strict | LineCount0 | SumDelayWaitingInLine | AheadCount | NumCompletedToday | NumScheduledNextW2 | DelayCount | InProgressSize | StartTime4 | AvgDelayForDay | AvgWaitLastK1Customers | SumDelayInProgress
# 13-feature model. Error:  23.57915967047999
# 14-feature model. Features: | DelayedInLine | LineCount0Strict | LineCount0 | SumDelayWaitingInLine | AheadCount | NumCompletedToday | NumScheduledNextW2 | DelayCount | InProgressSize | StartTime4 | AvgDelayForDay | AvgWaitLastK1Customers | SumDelayInProgress | NumScheduledNextSlot
# 14-feature model. Error:  23.548081793881664
# 15-feature model. Features: | DelayedInLine | LineCount0Strict | LineCount0 | SumDelayWaitingInLine | AheadCount | NumCompletedToday | NumScheduledNextW2 | DelayCount | InProgressSize | StartTime4 | AvgDelayForDay | AvgWaitLastK1Customers | SumDelayInProgress | NumScheduledNextSlot | IsFirst
# 15-feature model. Error:  23.52096351255369
# Best 15-feature model features: ['DelayedInLine', 'LineCount0Strict', 'LineCount0', 'SumDelayWaitingInLine', 'AheadCount', 'NumCompletedToday', 'NumScheduledNextW2', 'DelayCount', 'InProgressSize', 'StartTime4', 'AvgDelayForDay', 'AvgWaitLastK1Customers', 'SumDelayInProgress', 'NumScheduledNextSlot', 'IsFirst']
# Best error for the best {num_features_to_select}-feature model: 23.52096351255369

# %% [markdown]
# # Q9

# %%
from sklearn.linear_model import LinearRegression
from itertools import combinations
import numpy as np
from tqdm import tqdm

best_model = None
best_error = float('inf')

num_features_to_select = 3

feature_combinations = list(combinations(X.columns, num_features_to_select))

for features in tqdm(feature_combinations):
    X_subset = X[list(features)]
    
    model = LinearRegression()
    model.fit(X_subset, y)
    
    absolute_errors = np.abs(model.predict(X_subset) - y)
    error = absolute_errors.mean()
    
    if error < best_error:
        best_error = error
        best_model = (error, *features)

e = best_error

print(f"Best {num_features_to_select}-feature model features:", best_model[1:])
print(f"Error for the best {num_features_to_select}-feature model:", e)
# Out:
#   0%|          | 0/98770 [00:00<?, ?it/s]
# 100%|██████████| 98770/98770 [05:03<00:00, 325.21it/s]
# Best 3-feature model features: ('AheadCount', 'SumDelayWaitingByExamCode', 'NumCompletedToday')
# Error for the best 3-feature model: 26.072745167091245
